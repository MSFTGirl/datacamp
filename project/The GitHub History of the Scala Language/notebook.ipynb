# %% [markdown]
# ## 1. Scala's real-world project repository data
# <p>With almost 30k commits and a history spanning over ten years, Scala is a mature programming language. It is a general-purpose programming language that has recently become another prominent language for data scientists.</p>
# <p>Scala is also an open source project. Open source projects have the advantage that their entire development histories -- who made changes, what was changed, code reviews, etc. -- are publicly available. </p>
# <p>We're going to read in, clean up, and visualize the real world project repository of Scala that spans data from a version control system (Git) as well as a project hosting site (GitHub). We will find out who has had the most influence on its development and who are the experts.</p>
# <p>The dataset we will use, which has been previously mined and extracted from GitHub, is comprised of three files:</p>
# <ol>
# <li><code>pulls_2011-2013.csv</code> contains the basic information about the pull requests, and spans from the end of 2011 up to (but not including) 2014.</li>
# <li><code>pulls_2014-2018.csv</code> contains identical information, and spans from 2014 up to 2018.</li>
# <li><code>pull_files.csv</code> contains the files that were modified by each pull request.</li>
# </ol>

# %%
# Importing pandas
import pandas as pd
# ... YOUR CODE FOR TASK 1 ...

# Loading in the data
pulls_one = pd.read_csv('datasets/pulls_2011-2013.csv')
pulls_two = pd.read_csv('datasets/pulls_2014-2018.csv')
pull_files = pd.read_csv('datasets/pull_files.csv')

# %% [markdown]
# ## 2. Preparing and cleaning the data
# <p>First, we will need to combine the data from the two separate pull DataFrames. </p>
# <p>Next, the raw data extracted from GitHub contains dates in the ISO8601 format. However, <code>pandas</code> imports them as regular strings. To make our analysis easier, we need to convert the strings into Python's <code>DateTime</code> objects. <code>DateTime</code> objects have the important property that they can be compared and sorted.</p>
# <p>The pull request times are all in UTC (also known as Coordinated Universal Time). The commit times, however, are in the local time of the author with time zone information (number of hours difference from UTC). To make comparisons easy, we should convert all times to UTC.</p>

# %%
# Append pulls_one to pulls_two
pulls = pulls_two.append(pulls_one)

# Convert the date for the pulls object
pulls['date'] = pd.to_datetime(pulls['date'], utc=True)

# %% [markdown]
# ## 3. Merging the DataFrames
# <p>The data extracted comes in two separate files. Merging the two DataFrames will make it easier for us to analyze the data in the future tasks.</p>

# %%
# Merge the two DataFrames
data = pd.merge(pulls, pull_files, on='pid')

# %% [markdown]
# ## 4. Is the project still actively maintained?
# <p>The activity in an open source project is not very consistent. Some projects might be active for many years after the initial release, while others can slowly taper out into oblivion. Before committing to contributing to a project, it is important to understand the state of the project. Is development going steadily, or is there a drop? Has the project been abandoned altogether?</p>
# <p>The data used in this project was collected in January of 2018. We are interested in the evolution of the number of contributions up to that date.</p>
# <p>For Scala, we will do this by plotting a chart of the project's activity. We will calculate the number of pull requests submitted each (calendar) month during the project's lifetime. We will then plot these numbers to see the trend of contributions.</p>
# <ul>
# <li><p>A helpful reminder of how to access various components of a date can be found in <a href="https://campus.datacamp.com/courses/data-manipulation-with-pandas/slicing-and-indexing?ex=12">this exercise of Data Manipulation with pandas</a></p></li>
# <li><p>Additionally, recall that you can group by multiple variables by passing a list to <code>groupby()</code>. This video from <a href="https://campus.datacamp.com/courses/data-manipulation-with-pandas/aggregating-data-ad6d4643-0e95-470c-8299-f69cc4c83de8?ex=9">Data Manipulation with pandas</a> should help!</p></li>
# </ul>

# %%
# %matplotlib inline

# Create a column that will store the month
data['month'] = data['date'].dt.month

# Create a column that will store the year
data['year'] = data['date'].dt.year

# Group by the month and year and count the pull requests
counts = data.groupby(['month','year']).count()

# Plot the results
counts.plot(kind='bar', figsize = (12,4))

# %% [markdown]
# ## 5. Is there camaraderie in the project?
# <p>The organizational structure varies from one project to another, and it can influence your success as a contributor. A project that has a very small community might not be the best one to start working on. The small community might indicate a high barrier of entry. This can be caused by several factors, including a community that is reluctant to accept pull requests from "outsiders," that the code base is hard to work with, etc. However, a large community can serve as an indicator that the project is regularly accepting pull requests from new contributors. Such a project would be a good place to start.</p>
# <p>In order to evaluate the dynamics of the community, we will plot a histogram of the number of pull requests submitted by each user. A distribution that shows that there are few people that only contribute a small number of pull requests can be used as in indicator that the project is not welcoming of new contributors. </p>

# %%
# Required for matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# Group by the submitter
by_user = data['user'].value_counts()

# Plot the histogram
by_user.plot(kind = 'hist')
plt.show()

# %% [markdown]
# ## 6. What files were changed in the last ten pull requests?
# <p>Choosing the right place to make a contribution is as important as choosing the project to contribute to. Some parts of the code might be stable, some might be dead. Contributing there might not have the most impact. Therefore it is important to understand the parts of the system that have been recently changed. This allows us to pinpoint the "hot" areas of the code where most of the activity is happening. Focusing on those parts might not the most effective use of our times.</p>

# %%
# Identify the last 10 pull requests
last_10 = data.nlargest(10, 'date')

# Join the two data sets
joined_pr = last_10.merge(pull_files, on=['pid','file'], how='outer')

# Identify the unique files
files = set(joined_pr['file'])

# Print the results
files
# Out:
# {'test/files/run/reflect-priv-ctor.scala',
#  'test/files/run/t7398.scala',
#  'test/files/neg/macro-invalidsig.check',
#  'test/files/continuations-run/t1821.check',
#  'test/files/run/t5423.check',
#  'test/files/run/ctries-old/snapshot.scala',
#  'test/files/pos/t9181.scala',
#  'test/files/run/t5881.scala',
#  'test/files/neg/macro-invalidsig-tparams-bounds-a.check',
#  'test/files/jvm/unittest_xml.scala',
#  'src/compiler/scala/tools/ant/sabbus/Settings.scala',
#  'build.number',
#  'test/files/run/issue192.scala',
#  'test/files/neg/t8450.scala',
#  'src/actors/scala/actors/scheduler/ForkJoinScheduler.scala',
#  'test/files/pos/ypredef-multiple/minidef_1.scala',
#  'src/actors/scala/actors/threadpool/SynchronousQueue.java',
#  'src/compiler/scala/tools/nsc/symtab/Symbols.scala',
#  'test/files/presentation/t8085/src/nodescala/NodeScalaSuite.scala',
#  'test/files/run/idempotency-lazy-vals.check',
#  'src/jline/target/scala-2.9.2/classes/scala/tools/jline/WindowsTerminal$1.class',
#  'test/files/neg/t8244.check',
#  'test/files/run/icode-reader-dead-code.scala',
#  'test/files/pos/sip23-strings.scala',
#  'test/files/run/primitive-sigs-2-new.flags',
#  'test/files/neg/t3692-new.flags',
#  'test/files/neg/macro-invalidsig-tparams-notparams-b/Impls_1.scala',
#  'test/files/pos/t6815_import.scala',
#  'src/library/scala/runtime/java8/JFunction22.java',
#  'test/files/presentation/t8941b/Test.scala',
#  'src/continuations/plugin/scala/tools/selectivecps/SelectiveANFTransform.scala',
#  'test/files/run/t4172.check',
#  'test/files/instrumented/SI-4767-base/exec_2.scala',
#  'test/files/run/t8192/Macros_1.scala',
#  'src/forkjoin/scala/concurrent/forkjoin/RecursiveAction.java',
#  'test/files/neg/t2968b.scala',
#  'test/files/neg/warn-unused-imports.check',
#  'test/files/run/t6178.scala',
#  'test/files/run/virtpatmat_npe.flags',
#  'test/files/run/t5276_2a.check',
#  'test/files/scalacheck/quasiquotes/TypecheckedProps.scala',
#  'test/files/run/valueclasses-classtag-basic.check',
#  'test/files/scalacheck/testdir/test.scala',
#  'test/files/neg/macro-keyword-trait1.scala',
#  'test/pending/run/reify_for1.scala',
#  'test/files/run/delambdafy-two-lambdas.check',
#  'test/pending/run/repl-javap-more-fun.scala',
#  'src/library/scala/runtime/StringAdd.scala',
#  'test/files/neg/t6446-additional/sample_2.flags',
#  'test/files/run/t3575.flags',
#  'test/files/run/delambdafyLambdaClassNames/A_1.scala',
#  'test/files/neg/t5353.check',
#  'test/files/pos/t9552/t9552a.scala',
#  'test/files/run/reflection-mem-typecheck.scala',
#  'src/compiler/scala/tools/nsc/backend/jvm/BCodeGlue.scala',
#  'test/files/pos/t482.scala',
#  'test/files/run/macro-basic.check',
#  'test/files/presentation/t8941.check',
#  'test/files/neg/macro-invalidusage-badtargs-typemacros-c.flags',
#  'test/files/run/t5843.scala',
#  'src/compiler/scala/reflect/internal/Flags.scala',
#  'src/library/scala/util/parsing/combinator/syntactical/StandardTokenParsers.scala',
#  'test/files/neg/t5903d/Macros_1.scala',
#  'src/build/maven/scala-library-pom.xml',
#  'test/files/run/t4875.scala',
#  'test/files/neg/t7494-right-after-terminal/sample_2.flags',
#  'test/files/pos/t8359-closelim-crash.scala',
#  'test/files/run/macro-rangepos-subpatterns/Macros_1.scala',
#  'test/files/run/macro-range.flags',
#  'test/files/neg/t558.scala',
#  'test/files/run/macro-expand-tparams-prefix-a/Impls_1.scala',
#  'src/xml/scala/xml/parsing/FactoryAdapter.scala',
#  'src/manual/scala/man1/sbaz.scala',
#  'test/pending/run/macro-expand-implicit-macro-defeats-type-inference.check',
#  'src/reflect/scala/reflect/macros/Synthetics.scala',
#  'test/files/scalap/valAndVar.scala',
#  'test/files/neg/macro-nontypeablebody-typemacros/Impls_1.scala',
#  'test/files/run/t5704.check',
#  'test/files/neg/t7187.flags',
#  'src/library/scala/StringContext.scala',
#  'test/files/pos/t6574.scala',
#  'test/files/run/t4080.check',
#  'test/files/jvm/patmat_opt_ignore_underscore/test.scala',
#  'test/files/run/t6406-regextract.scala',
#  'test/pending/run/t3899.check',
#  'src/reflect/scala/reflect/dynamic/DynamicProxy.scala',
#  'test/files/pos/t531.scala',
#  'test/files/neg/t8092.check',
#  'test/files/run/t6715.scala',
#  'test/files/neg/t10081.check',
#  'test/files/neg/t9527b.check',
#  'spec/09-implicit-parameters-and-views.md',
#  'test/files/run/t6502.scala',
#  'test/files/run/t2296b/J_1.java',
#  'src/xml/scala/xml/MetaData.scala',
#  'src/compiler/scala/tools/nsc/Reporting.scala',
#  'test/files/run/t3452g/A.scala',
#  'test/files/run/macro-def-infer-return-type-typemacros/Macros_Test_2.scala',
#  'docs/examples/plugintemplate/test/plugintemplate/PluginPropertiesSuite.scala',
#  'test/files/pos/t8352/Test_2.scala',
#  'test/disabled/presentation/ide-bug-1000450/src/Ranges.scala',
#  'test/files/neg/t6074.scala',
#  'test/files/neg/virtpatmat_exhaust_compound.check',
#  'test/files/pos/t9479.scala',
#  'src/library/scala/reflect/compat.scala',
#  'test/files/neg/t9127.flags',
#  'test/disabled/presentation/timeofday/src/timeofday.scala',
#  'test/files/pos/patmat_tuple_opt_erasure.flags',
#  'test/files/run/macro-impl-tparam-only-in-impl/Impls_1.scala',
#  'src/library/scala/collection/script/Message.scala',
#  'src/intellij/scala-lang.ipr.SAMPLE',
#  'src/library/scala/Predef.scala',
#  'test/files/neg/macro-override-macro-overrides-macrotype-b/Macros_Test_2.scala',
#  'test/files/jvm/actmig-PinS.check',
#  'src/library/scala/Tuple1.scala',
#  'src/library/scala/collection/mutable/Stack.scala',
#  'src/eclipse/README',
#  'src/library/scala/runtime/LambdaDeserialize.java',
#  'src/asm/scala/tools/asm/util/TraceAnnotationVisitor.java',
#  'test/files/run/virtpatmat_switch.check',
#  'test/files/pos/sip23-valueof-alias.scala',
#  'test/files/run/t7246.check',
#  'test/files/run/t9029.scala',
#  'test/files/run/t10587.javaopts',
#  'classpath.SAMPLE',
#  'test/files/run/repl-javap-lambdas.scala',
#  'src/asm/scala/tools/asm/tree/AnnotationNode.java',
#  'tools/CopyrightDateTool.scala',
#  'src/library/scala/runtime/java8/JProcedure13.java',
#  'test/files/neg/t112706A.check',
#  'test/scaladoc/run/t8407.scala',
#  'docs/examples/plugintemplate/build.xml',
#  'test/files/run/t10284.check',
#  'docs/examples/sort2.scala',
#  'test/files/buildmanager/t2790/A.scala',
#  'test/pending/continuations-run/foreach.scala',
#  'src/compiler/scala/tools/nsc/settings/AbsSettings.scala',
#  'src/partest/scala/tools/partest/nest/FileManager.scala',
#  'test/files/neg/t6264.check',
#  'test/files/run/t6327.scala',
#  'test/files/run/t2721.scala',
#  'test/files/run/t7291a.scala',
#  'src/actors/scala/actors/threadpool/helpers/ThreadHelpers.java',
#  'test/files/pos/virtpatmat_exist3.flags',
#  'test/files/run/t6584.check',
#  'test/files/neg/macro-bundle-priority-nonbundle.scala',
#  'test/files/continuations-run/ts-1681.check',
#  'test/files/neg/t5923c.check',
#  'src/library/scala/Responder.scala',
#  'test/files/run/t3507-new.scala',
#  'test/disabled/neg/macro-keyword-package1.scala',
#  'test/files/neg/kind-poly3.scala',
#  'test/files/neg/t5954.flags',
#  'test/files/neg/t6574.check',
#  'test/files/jvm/throws-annot.scala',
#  'test/files/run/macro-reify-chained1/Test_2.scala',
#  'test/files/jvm/actor-uncaught-exception2.check',
#  'test/files/run/t5313.scala',
#  'test/files/run/t7880.scala',
#  'test/pending/buildmanager/t2443/BitSet.scala',
#  'docs/examples/parsing/lambda/TestParser.scala',
#  'test/files/run/toolbox_silent_reporter.scala',
#  'src/jline/src/main/resources/scala/tools/jline/keybindings.properties',
#  'test/files/jvm/xmlstuff.check',
#  'test/files/run/t7120.check',
#  'test/files/neg/unit-returns-value.scala',
#  'test/benchmarks/src/scala/collection/parallel/benchmarks/parallel_array/Corresponds.scala',
#  'src/compiler/scala/tools/nsc/interpreter/ISettings.scala',
#  'test/scaladoc/run/inlineToStrForTitleTag.check',
#  'test/scaladoc/run/t6626.check',
#  'test/files/run/t9223b.scala',
#  'test/pending/run/t5695/part_1.scala',
#  'test/disabled/script/second.check',
#  'test/files/neg/t7655.scala',
#  'test/files/neg/macro-invalidusage-badargs-c/Macros_Test_2.scala',
#  'test/files/neg/t7783.check',
#  'src/library/scala/sys/process/ProcessBuilderImpl.scala',
#  'test/files/run/t6168b/main.scala',
#  'src/intellij/junit.iml.SAMPLE',
#  'src/msil/ch/epfl/lamp/compiler/msil/CallingConventions.java',
#  'test/files/pos/no-widen-locals.scala',
#  'src/library/scala/beans/BeanDescription.scala',
#  'test/files/neg/t3816.scala',
#  'test/files/pos/t6204-a.scala',
#  'test/files/scalap/packageObject.scala',
#  'test/pending/shootout/fasta.scala',
#  'test/files/pos/t3417.scala',
#  'test/files/pos/t2956/t2956.scala',
#  'test/files/neg/t8104.check',
#  'test/scaladoc/run/SI-4324.check',
#  'src/compiler/scala/tools/nsc/util/ScalaClassLoader.scala',
#  'test/files/pos/spec-constr-new.scala',
#  'test/files/buildmanager/t2653/t2653.check',
#  'src/scaladoc/scala/tools/nsc/doc/html/resource/lib/lato-v11-latin-regular.ttf',
#  'test/files/run/t10522.check',
#  'src/library/scala/runtime/ScalaRunTime.scala',
#  'test/files/neg/macro-invalidsig/Impls_1.scala',
#  'src/asm/scala/tools/asm/tree/TypeInsnNode.java',
#  'src/library/scala/runtime/LambdaDeserializer.scala',
#  'test/files/run/reflection-sanitychecks.check',
#  'src/compiler/scala/tools/nsc/doc/html/resource/lib/type_to_object_big.png',
#  'test/files/run/t8935-object.check',
#  'test/disabled/presentation/shutdown-deadlock/src/arrays.scala',
#  'buildcharacter.properties',
#  'test/pending/pos/t5589.scala',
#  'test/files/run/t5652/t5652_2.scala',
#  'test/files/continuations-run/ifelse1.scala',
#  'src/compiler/scala/reflect/makro/runtime/Reifiers.scala',
#  'src/actors/scala/actors/remote/Service.scala',
#  'src/library/scala/xml/NamespaceBinding.scala',
#  'test/files/detach-run/actor/actor.scala',
#  'test/files/run/macro-expand-tparams-bounds.check',
#  'test/files/run/repl-javap-memfun.scala',
#  'test/files/jvm/actor-receivewithin.check',
#  'test/files/run/t4287c.scala',
#  'test/files/ant/scalac001.scala',
#  'test/files/run/t6240a/Test.scala',
#  'src/reflect/scala/reflect/io/Path.scala',
#  'src/jline/src/main/java/scala/tools/jline/console/Operation.java',
#  'test/files/pos/t8060.scala',
#  'test/files/jvm/actmig-receive.check',
#  'test/junit/scala/tools/nsc/typechecker/Infer.scala',
#  'test/files/pos/t1029.cmds',
#  'src/jline/src/main/java/scala/tools/jline/AnsiWindowsTerminal.java',
#  'test/files/pos/t6089b.scala',
#  'src/build/bnd/scala-continuations-plugin.bnd',
#  'test/files/presentation/partial-fun.check',
#  'src/scalap/scala/tools/scalap/scalasig/Symbol.scala',
#  'src/intellij-14/reflect.iml.SAMPLE',
#  'test/pending/pos/treecheckers/c1.scala',
#  'src/compiler/scala/tools/nsc/typechecker/Modes.scala',
#  'src/eclipse/scalap/.gitignore',
#  'test/files/neg/ypredef-custom/minidef_1.scala',
#  'test/files/neg/macro-bundle-overloaded.check',
#  'docs/examples/boundedbuffer.scala',
#  'test/files/run/macro-expand-implicit-macro-is-val/Macros_Test_2.scala',
#  'test/files/run/t4625c.scala',
#  'test/files/neg/macro-invalidshape/Impls_1.scala',
#  'test/files/pos/t6896.scala',
#  'test/scalacheck/duration.scala',
#  'src/interactive/scala/tools/nsc/interactive/PresentationCompilerThread.scala',
#  'src/actors/scala/actors/ActorProxy.scala',
#  'test/files/pos/no-string-plus-1.scala',
#  'src/library/scala/collection/generic/ParMapFactory.scala',
#  'test/files/neg/t3691.check',
#  'src/library/scala/concurrent/Lock.scala',
#  'src/compiler/scala/tools/nsc/interpreter/Results.scala',
#  'test/pending/run/reify_sort1.check',
#  'test/disabled/run/macro-reflective-mamd-normal-mi.flags',
#  'test/files/neg/kind-poly-noflag.scala',
#  'test/files/neg/t2712-2.flags',
#  'test/files/neg/t5821.scala',
#  'test/files/run/reify_extendbuiltins.check',
#  'test/files/run/t7871/Test_2.scala',
#  'test/files/run/macro-def-path-dependent-a.flags',
#  'test/files/neg/t8015-ffb.scala',
#  'test/files/run/macro-expand-overload/Macros_Test_2.scala',
#  'src/scaladoc/scala/tools/nsc/doc/html/resource/lib/trait_big.png',
#  'test/files/neg/t7369.scala',
#  'test/files/run/t5328.check',
#  'src/repl/scala/tools/nsc/interpreter/PresentationCompilerCompleter.scala',
#  'test/files/neg/t9248.flags',
#  'test/files/pos/t1107a.scala',
#  'src/library/scala/concurrent/util/duration/NumericMultiplication.scala',
#  'test/scaladoc/resources/doc-root/AnyRef.scala',
#  'test/files/neg/patmat-type-check.check',
#  'test/files/neg/analyzerReplacingPlugins-a.check',
#  'test/files/run/macro-expand-implicit-macro-has-implicit-typemacros.check',
#  'test/files/run/t6353.scala',
#  'test/files/neg/macro-invalidusage-badargs-typemacros-b.flags',
#  'test/files/neg/t5760-pkgobj-warn.check',
#  'test/files/neg/t7285.check',
#  'test/files/neg/t1705.check',
#  'test/files/run/macro-parse-position-malformed/Test_2.scala',
#  'test/files/neg/t2509-4.check',
#  'test/files/pos/t7126.scala',
#  'test/files/run/macro-def-path-dependent-d1/Impls_Macros_1.scala',
#  'test/files/pos/t9208.flags',
#  'test/scaladoc/run/diagrams-inherited-nodes.scala',
#  'test/files/run/lazy-exprs.check',
#  'test/files/neg/constructor-prefix-error.check',
#  'test/files/pos/t10623.flags',
#  'src/reflect/scala/reflect/internal/CompileRunAborted.scala',
#  'src/compiler/scala/tools/util/SocketServer.scala',
#  'test/files/neg/t6593.scala',
#  'src/subscript/subscript/DSL.scala',
#  'test/files/jvm/beanInfo/C_1.scala',
#  'test/files/pos/t6485a/Test_2.scala',
#  'test/files/scalacheck/quasiquotes/LiftableProps.scala',
#  'src/compiler/scala/tools/nsc/symtab/SymbolTable.scala',
#  'test/files/pos/byname-implicits-7.scala',
#  'test/files/run/sourcelocation-chain.scala',
#  'test/files/run/reify-each-node-type.scala',
#  'test/files/run/t7269.scala',
#  'test/files/run/t5943a1.scala',
#  'test/files/scalap/typeAnnotations.check',
#  'src/compiler/scala/tools/nsc/backend/ScalaPrimitives.scala',
#  'src/library/scala/util/grammar/HedgeRHS.scala',
#  'test/files/neg/t6895.check',
#  'test/files/run/si7375.check',
#  'test/disabled/buildmanager/t2651_1/B.scala',
#  'test/scaladoc/scalacheck/DeprecatedIndexTest.scala',
#  'src/repl-frontend/scala/tools/nsc/interpreter/shell/Parsed.scala',
#  'test/files/neg/t715.scala',
#  'test/manual-classpath-test/cp-and-sp-test/orig-src/h/i/E.scala',
#  'test/files/neg/typemacros-incomplete-a.check',
#  'test/files/run/StubErrorTypeclass.check',
#  'test/files/run/t5545.scala',
#  'src/scaladoc/scala/tools/nsc/doc/html/page/Index.scala',
#  'src/library/scala/collection/mutable/SynchronizedQueue.scala',
#  'test/pending/continuations-run/foreach.check',
#  'test/pending/pos/t5503.flags',
#  'test/files/run/si7375.scala',
#  'project/build/ScalaSBTBuilder.scala',
#  'test/files/neg/macro-invalidimpl-i.flags',
#  'src/eclipse/partest/.gitignore',
#  'test/files/run/macro-openmacros/Impls_Macros_1.scala',
#  'test/pending/buildmanager/t2443/t2443.check',
#  'src/eclipse/scaladoc/.gitignore',
#  'test/files/neg/t8015-ffa.scala',
#  'test/files/neg/t6446-show-phases.flags',
#  'src/library/scala/annotation/unspecialized.scala',
#  'test/files/run/kind-poly9.flags',
#  'src/compiler/scala/tools/nsc/classpath/FlatClassPathFactory.scala',
#  'test/files/neg/t9572.check',
#  'src/jline/target/scala-2.9.2/classes/scala/tools/jline/console/ConsoleReader.class',
#  'test/files/run/t5699.check',
#  'test/files/run/t10526.scala',
#  'test/files/continuations-run/t2934.check',
#  'src/subscript/subscript/vm/CodeExecutor.scala',
#  'test/files/run/reify_closure7.scala',
#  'test/files/pos/t5031_3/Main_2.scala',
#  'test/pending/run/t5266_1.scala',
#  'src/compiler/scala/tools/nsc/ReflectMain.scala',
#  'test/junit/scala/tools/nsc/backend/jvm/opt/ClosureOptimizerTest.scala',
#  'src/library/scala/collection/Searching.scala',
#  'test/files/run/t6775.check',
#  'src/jline/target/scala-2.9.2/classes/scala/tools/jline/console/Key.class',
#  'test/files/run/t4897.scala',
#  'src/reflect/scala/reflect/runtime/internal/ReflectionUtils.scala',
#  'test/files/neg/trailing-commas.scala',
#  'test/files/run/t6706.scala',
#  'src/library/scala/collection/parallel/ParMap.scala',
#  'test/files/run/sip23-rangepos.flags',
#  'src/compiler/scala/reflect/internal/MissingRequirementError.scala',
#  'src/compiler/scala/tools/nsc/settings/AdvancedScalaSettings.scala',
#  'src/compiler/scala/reflect/internal/FatalError.scala',
#  'test/files/run/t10107/A_1.java',
#  'src/reflect/scala/reflect/runtime/Gil.scala',
#  'src/library/scala/util/parsing/combinator/PackratParsers.scala',
#  'test/files/run/sip-23-implicit-resolution.scala',
#  'test/files/run/analyzerReplacingPlugins/sample_2.scala',
#  'test/files/run/t8245.scala',
#  'src/compiler/scala/tools/nsc/interpreter/Pasted.scala',
#  'test/files/run/existentials.scala',
#  'src/xml/scala/xml/dtd/impl/WordExp.scala',
#  'test/files/neg/macro-invalidimpl-c.flags',
#  'src/jline/src/main/java/scala/tools/jline/console/completer/ArgumentCompleter.java',
#  'test/files/run/function-null-unbox.scala',
#  'src/detach/plugin/scala/tools/detach/Detach.scala',
#  'src/library/scala/reflect/base/TypeTags.scala',
#  'test/disabled/coder/Dictionary.scala',
#  'test/scaladoc/run/SI-9704.check',
#  'test/disabled-windows/script/loadAndExecute/lAndE2.scala',
#  'test/files/neg/t9781.scala',
#  'test/files/run/top-level-definitions.scala',
#  'test/files/ant/fsc003.scala',
#  'test/files/run/reify_implicits-new.scala',
#  'test/files/neg/t2870.scala',
#  'test/files/pos/t9111-inliner-workaround/Test_1.scala',
#  'test/files/scalacheck/parallel-collections/ParallelCtrieCheck.scala',
#  'src/compiler/scala/tools/util/SignalManager.scala',
#  'src/reflect/scala/reflect/io/VirtualDirectory.scala',
#  'test/manual-classpath-test/cp-and-sp-test/orig-src/Main.scala',
#  'test/files/run/reify_newimpl_40.check',
#  'test/scaladoc/run/diagrams-filtering.check',
#  'test/files/neg/t5578.check',
#  'test/files/neg/macro-invalidimpl-d/Macros_Test_2.scala',
#  'src/library/scala/collection/mutable/LinkedEntry.scala',
#  'test/files/pos/t1626.scala',
#  'src/build/bnd/scala-compiler-interactive.bnd',
#  'test/files/run/t4788/S.scala',
#  'test/files/neg/t7622-multi-followers.check',
#  'test/files/presentation/t8941/src/Source.scala',
#  'test/pending/pos/t4436.scala',
#  'test/disabled/neg/macro-invalidshape-d/Impls_1.scala',
#  'sree',
#  'test/files/buildmanager/t2557/B.scala',
#  'src/library/scala/reflect/ClassTag.scala',
#  'tools/binary-repo-lib.sh',
#  'test/files/scalap/abstractMethod/result.test',
#  'test/files/neg/t5189_inferred.scala',
#  'src/library/scala/annotation/Annotation.scala',
#  'test/files/pos/t5692b.flags',
#  'test/files/ant/scalac002-build.xml',
#  'test/files/pos/t3883.scala',
#  'src/compiler/scala/tools/nsc/transform/Mixin.scala',
#  'docs/licenses/mit_jquery-layout.txt',
#  'test/files/run/t10490-2/JavaClass.java',
#  'test/files/run/t9375.check',
#  'test/files/neg/t2148.scala',
#  'test/files/neg/t5753/Impls$class.class',
#  'src/compiler/scala/reflect/internal/util/Origins.scala',
#  'test/files/run/t5293-map.scala',
#  'test/files/run/macro-expand-unapply-b.flags',
#  'test/files/lib/genericNest.jar.desired.sha1',
#  'test/files/neg/t4541.scala',
#  'test/files/disabled/overloaded_1.check',
#  'test/files/neg/t5689.scala',
#  'test/files/pos/virtpatmat_gadt_array.flags',
#  'test/files/run/adding-growing-set.scala',
#  'test/junit/scala/collection/IteratorTest.scala',
#  'test/files/run/arraytags_usage.scala',
#  'src/compiler/scala/tools/nsc/doc/html/resource/lib/object_to_class_big.png',
#  'test/files/run/repl-imports.check',
#  'test/files/run/sip23-macro-eval/Test_2.scala',
#  'test/files/pos/t8934a/Test_2.scala',
#  'test/files/scalap/defaultParameter.scala',
#  'test/files/neg/t9636.scala',
#  'test/files/run/sip23-cast-0.scala',
#  'src/compiler/scala/tools/nsc/interpreter/session/package.scala',
#  'src/library/scala/concurrent/SyncVar.scala',
#  'src/compiler/scala/tools/nsc/PhaseAssembly.scala',
#  'spec/public/fonts/LuxiSans-Bold.woff',
#  'test/benchmarking/ParCtrie-bfs.scala',
#  'test/files/neg/unchecked-abstract.scala',
#  'test/files/jvm/reactor-producer-consumer.scala',
#  'test/files/run/t6104.check',
#  'test/files/neg/t8685.scala',
#  'test/pending/pos/t4123.scala',
#  'test/files/neg/annot-nonconst.check',
#  'docs/licenses/apache_android.txt',
#  'src/library/scala/util/automata/WordBerrySethi.scala',
#  'src/compiler/scala/tools/nsc/interactive/Global.scala',
#  'test/pending/pos/t1751/SuiteClasses.java',
#  'src/library/scala/xml/UnprefixedAttribute.scala',
#  'test/benchmarks/src/main/scala/scala/StringInterpolationBenchmark.scala',
#  'test/files/neg/override-object-no.check',
#  'test/files/run/t5277_2.scala',
#  'src/compiler/scala/tools/nsc/io/ClassAndJarInfo.scala',
#  'test/files/run/t3368-c.scala',
#  'test/files/neg/userdefined_apply.scala',
#  'src/swing/scala/swing/LayoutContainer.scala',
#  'test/files/pos/t7864.flags',
#  'test/files/run/idempotency-this.check',
#  'src/compiler/rootdoc.txt',
#  'test/files/ant/fsc002.scala',
#  'test/files/pos/annotated-original/C_2.scala',
#  'src/xml/scala/xml/QNode.scala',
#  'src/compiler/scala/tools/nsc/transform/patmat/MatchCodeGen.scala',
#  'src/library/scala/runtime/LazyRef.scala',
#  'test/files/presentation/t8934/src/Source.scala',
#  'test/files/run/t8190.check',
#  'test/files/run/lists-run.scala',
#  'test/files/run/t9102.scala',
#  'test/files/neg/macro-keyword-var.check',
#  'src/fjbg/ch/epfl/lamp/fjbg/JMember.java',
#  'test/files/run/t5923a/Macros_1.scala',
#  'test/pending/presentation/context-bounds1/src/ContextBounds.scala',
#  'test/files/pos/t2726.cmds',
#  'test/files/run/collections.scala',
#  'test/files/neg/t5887.check',
#  'src/compiler/scala/tools/nsc/transform/ExplicitOuter.scala',
#  'test/files/pos/t9717.scala',
#  'test/files/neg/val_infer.scala',
#  'test/files/pos/t3688.scala',
#  'test/files/neg/macro-invalidsig-params-namemismatch.check',
#  'docs/development/scala.tools.nsc/zipfile-bug.txt',
#  'test/files/pos/t10394.scala',
#  'src/compiler/scala/reflect/macros/runtime/Infrastructure.scala',
#  'test/scaladoc/resources/doc-root/Any.scala',
#  'test/scaladoc/run/SI-191-deprecated.check',
#  'test/files/neg/macro-expand-varargs-a/Test_2.scala',
#  'test/files/neg/macro-without-xmacros-b.check',
#  'test/disabled/neg/macro-keyword-bind.check',
#  'tools/scaladoc-diff',
#  'test/files/neg/macro-invalidusage-badargs-typemacros-b/Impls_1.scala',
#  'test/files/run/t5903c/Macros_1.scala',
#  'test/files/run/t6814.check',
#  'test/files/continuations-neg/t5314-npe.check',
#  'test/files/run/t6536.scala',
#  'test/files/neg/t5365b.scala',
#  'src/library/scala/collection/mutable/GenMap.scala.disabled',
#  'test/files/pos/userdefined_apply_poly_overload.flags',
#  'test/files/run/t7046.check',
#  'src/library/scala/xml/Utility.scala',
#  'src/library/scala/util/hashing/Hashing.scala',
#  'test/junit/scala/collection/mutable/ArrayBufferTest.scala',
#  'test/benchmarks/src/main/scala/scala/collection/immutable/VectorMapBenchmark.scala',
#  'test/files/run/macro-bundle-whitebox-decl.check',
#  'test/files/run/lazy-locals.scala',
#  'test/files/pos/t8224.scala',
#  'test/files/run/array-charSeq.scala',
#  'test/files/jvm/actmig-PinS_2.scala',
#  'src/library/scala/Product.scala',
#  'test/files/run/virtpatmat_typetag.check',
#  'test/files/run/macro-def-path-dependent-a/Impls_Macros_1.scala',
#  'test/files/neg/macro-invalidimpl-g.flags',
#  'test/files/neg/t1477.scala',
#  'test/files/neg/macro-nontypeablebody-typemacros.check',
#  'test/benchmarks/src/scala/collection/parallel/benchmarks/parallel_array/ForeachLight.scala',
#  'test/files/neg/t6666c.flags',
#  'test/disabled/script/fact.args',
#  'test/files/pos/sd248/Prop_1.scala',
#  'src/library/scala/collection/immutable/TreeMap.scala',
#  'test/files/pos/sam_infer_argtype_subtypes.scala',
#  'src/library/scala/collection/parallel/immutable/ParSeq.scala',
#  'test/files/run/uncurry_inline.scala',
#  'src/scaladoc/scala/tools/nsc/doc/html/resource/lib/ownerbg.gif',
#  'test/files/neg/extra-predef-no-imports/minidef_1.scala',
#  'test/files/run/macro-expand-implicit-macro-is-implicit/Macros_Test_2.scala',
#  'test/files/neg/t5390d.scala',
#  'test/files/run/t3667.check',
#  'src/library/scala/concurrent/BlockContext.scala',
#  'test/files/neg/t5689.flags',
#  'src/library/scala/collection/mutable/SynchronizedMap.scala',
#  'test/files/scalacheck/duration.scala',
#  'src/compiler/scala/reflect/internal/NameManglers.scala',
#  'src/library/scala/collection/Parallelizable.scala',
#  'test/files/run/t5923c.flags',
#  'test/files/run/dynamic-proxy.flags',
#  'src/compiler/scala/reflect/internal/AbstractFileApi.scala',
#  'test/files/run/t6591_3.check',
#  'test/files/run/nothingTypeDce.flags',
#  'test/files/pos/depmet_implicit_norm_ret.scala',
#  'test/files/presentation/t4287c/src/Foo.scala',
#  'test/files/run/exceptions-2.scala',
#  'test/files/neg/t6795.scala',
#  'test/files/pos/t5240.scala',
#  '.project.SAMPLE',
#  'test/files/instrumented/indy-symbol-literal.scala',
#  'test/junit/scala/tools/nsc/backend/bcode/JumpChainsUnit1Test.scala',
#  'test/files/pos/kind-poly3.flags',
#  'test/files/run/t7459d.scala',
#  'test/files/run/static-annot-repl.scala',
#  'src/compiler/scala/tools/nsc/settings/AestheticSettings.scala',
#  'spec/public/fonts/Heuristica-BoldItalic.woff',
#  'test/files/pos/t3234.scala',
#  'test/files/run/macro-term-declared-in-method.check',
#  'test/files/neg/parser-import-errors.check',
#  'src/library/scala/collection/parallel/immutable/ParSet.scala',
#  'test/pending/run/t8582-bcode.check',
#  'src/compiler/scala/tools/reflect/FrontEnds.scala',
#  'src/library/scala/reflect/ClassManifest.scala',
#  'test/files/run/patmat-behavior-2.check',
#  'test/files/run/t10389.scala',
#  'test/files/pos/t4695a/A_2.scala',
#  'test/files/buildmanager/t2650_2/B.scala',
#  'test/files/run/t6261.scala',
#  'test/files/neg/t7494-multi-right-after/ThePlugin.scala',
#  'test/files/pos/t8617.scala',
#  'test/files/run/t6900.scala',
#  'test/files/run/erasuretags_usage.scala',
#  'test/files/neg/t5692b/Test_2.scala',
#  'src/compiler/scala/tools/nsc/typechecker/MethodSynthesis.scala',
#  'test/files/run/t5744/Test_2.scala',
#  'test/files/neg/macro-invalidimpl-h.check',
#  'src/library/scala/collection/parallel/Combiner.scala',
#  'test/files/run/repl-term-macros.check',
#  'test/disabled/run/t2886.scala',
#  'docs/examples/actors/seq.scala',
#  'src/swing/scala/swing/RootPanel.scala',
#  'test/files/positions/ExcludedPrefix1.scala',
#  'src/partest-extras/scala/tools/partest/ReplTest.scala',
#  'src/jline/LICENSE.txt',
#  'bugs-fixed.txt',
#  'test/files/pos/t6891.flags',
#  'src/compiler/scala/reflect/reify/Reifier.scala',
#  'test/files/run/tailcalls.check',
#  'test/scaladoc/run/t5527.scala',
#  'src/intellij-14/README',
#  'test/files/neg/t9286b.scala',
#  'src/library/scala/collection/mutable/Buffer.scala',
#  'src/actors/scala/actors/threadpool/Executor.java',
#  'test/files/neg/t7475c.scala',
#  'test/files/neg/t7494-multi-right-after/scalac-plugin.xml',
#  'test/files/run/t6187b.scala',
#  'src/library/scala/reflect/base/Constants.scala',
#  'src/compiler/scala/tools/asm/Handler.java',
#  'test/files/run/t8690.scala',
#  'src/scaladoc/scala/tools/nsc/doc/model/Visibility.scala',
#  'test/files/run/StubErrorTypeDef.scala',
#  'test/scaladoc/run/SI-6140.check',
#  'test/files/run/inferred-type-constructors-hou.check',
#  'src/compiler/scala/reflect/reify/utils/NodePrinters.scala',
#  'test/files/presentation/callcc-interpreter/Runner.scala',
#  'test/scaladoc/run/SI-3448.check',
#  'test/files/run/reify_ann1a.check',
#  'src/actors/scala/actors/MQueue.scala',
#  'test/files/run/reify_renamed_term_overloaded_method.scala',
#  'test/files/run/dead-code-elimination.flags',
#  'test/files/run/macro-declared-in-object-class/Impls_1.scala',
#  'test/files/neg/t7289.scala',
#  'test/files/run/t5488-fn.flags',
#  'test/files/run/cp-cmd/ClasspathTest.class',
#  'test/files/pos/t6162-inheritance.flags',
#  'test/files/run/macroPlugins-isBlackbox/Macros_2.scala',
#  'test/files/presentation/hyperlinks/Runner.scala',
#  'test/files/run/macro-bundle-whitebox-use-refined/Macros_1.scala',
#  'test/files/neg/macro-keyword-package1.check',
#  'src/library/scala/reflect/makro/Exprs.scala',
#  'test/files/neg/t6895b.scala',
#  'test/files/pos/t3568.scala',
#  'test/files/run/macro-term-declared-in-annotation/Test_3.scala',
#  'test/files/continuations-run/ts-1681-2.check',
#  'src/library/scala/runtime/java8/JProcedure21.java',
#  'test/files/neg/macro-roles.flags',
#  'src/library/scala/runtime/java8/JFunction2$mcFDD$sp.java',
#  'src/library/scala/collection/generic/CanBuildFrom.scala',
#  'test/files/run/t7747-repl/repl-class-based-wrappers.scala',
#  'src/intellij-14/interactive.iml.SAMPLE',
#  'test/files/run/dynamicproxy-access-private.check',
#  'test/files/run/macro-rangepos-subpatterns.flags',
#  'test/files/neg/t4440.check',
#  'test/files/neg/literals.scala',
#  'spec/public/fonts/Heuristica-Bold.woff',
#  'test/files/neg/macro-override-macro-overrides-abstract-method-b/Impls_Macros_1.scala',
#  'test/files/neg/t2509-3.flags',
#  'test/files/pos/t3498-new.scala',
#  'test/files/run/macro-bodyexpandstoimpl/Macros_Test_2.scala',
#  'test/disabled/script/t1015.scala',
#  'test/files/run/t7843-jsr223-service.scala',
#  'test/files/run/macro-term-declared-in-object-class.check',
#  'test/files/run/t6353.check',
#  'src/library/scala/runtime/java8/JFunction1$mcVF$sp.java',
#  'test/files/neg/t6263.check',
#  'test/files/pos/sammy_implicit.scala',
#  'test/files/run/macro-expand-varargs-implicit-over-nonvarargs.check',
#  'test/scaladoc/resources/implicit-inheritance-usecase.scala',
#  'test/files/run/t3452b-bcode/S_1.scala',
#  'scripts/jobs/integrate/ide',
#  'src/library/scala/sys/process/Process.scala',
#  'src/library/scala/Function0.scala',
#  'test/files/neg/t9684.check',
#  'test/files/neg/macro-bundle-nonmacro.scala',
#  'test/files/scalap/caseObject.check',
#  'test/files/run/macro-declared-in-refinement.check',
#  'test/files/neg/t5760-pkgobj-warn/stalepkg_2.scala',
#  'test/pending/run/reify_closure4b.scala',
#  'test/files/pos/t6552.scala',
#  'docs/examples/actors/producers.scala',
#  'test/files/pos/t6664.scala',
#  'src/partest/scala/tools/partest/nest/RunnerUtils.scala',
#  'test/files/run/t8570a.scala',
#  'src/library/scala/reflect/api/FreeVars.scala',
#  'src/scaladoc/scala/tools/nsc/doc/html/resource/lib/type_big.png',
#  'test/pending/run/origins.check',
#  'src/library/scala/specialized.scala',
#  'src/library/scala/util/matching/Regex.scala',
#  'test/files/run/reify_for1.check',
#  'src/library/scala/collection/SortedSet.scala',
#  'test/files/neg/t5903b.check',
#  'test/files/run/t7556/mega-class_1.scala',
#  'test/files/neg/t9398.flags',
#  'test/files/pos/macro-qmarkqmarkqmark.check',
#  'test/files/run/t6637.check',
#  'src/parser-combinators/scala/util/parsing/combinator/token/Tokens.scala',
#  'test/files/run/t7319.scala',
#  'test/files/run/reflection-package-name-conflict/A_1.scala',
#  'test/files/neg/macro-invalidshape-b.check',
#  'src/library/scala/xml/NodeSeq.scala',
#  'test/files/run/t10454-2/Test_2.scala',
#  'test/junit/scala/collection/MapLikeTest.scala',
#  'test/files/neg/t8015-ffa.check',
#  'src/msil/ch/epfl/lamp/compiler/msil/PropertyAttributes.java',
#  'test/files/run/t6394a.flags',
#  'src/reflect/mima-filters/2.12.0.backwards.excludes',
#  'test/files/neg/t4871.check',
#  'test/files/run/interop_concretetypetags_are_classmanifests.check',
#  'test/files/neg/t0218.check',
#  'src/library/scala/SpecializableCompanion.scala',
#  'src/intellij/repl-frontend.iml.SAMPLE',
#  'test/files/run/macro-rangepos-subpatterns/Test_2.scala',
#  'src/compiler/scala/tools/nsc/plugins/Plugins.scala',
#  'docs/examples/patterns.scala',
#  'src/library/scala/concurrent/DelayedLazyVal.scala',
#  'test/files/neg/t10066.check',
#  'src/scaladoc/scala/tools/nsc/doc/Uncompilable.scala',
#  'test/files/run/ctries-old/iterator.scala',
#  'test/files/pos/t5639.flags',
#  'src/compiler/scala/tools/nsc/settings/FscSettings.scala',
#  'test/files/buildmanager/t3133/t3133.test',
#  'src/asm/scala/tools/asm/CurrentFrame.java',
#  'test/files/pos/t8411/Test_2.scala',
#  'src/compiler/scala/tools/nsc/typechecker/Macros.scala',
#  'test/files/run/t6070.check',
#  'test/files/pos/t5305.scala',
#  'test/files/run/t8960.scala',
#  'test/files/pos/t1459/Caller.java',
#  'test/files/run/t10042/Checks_0.scala',
#  'test/files/neg/macro-blackbox-dynamic-materialization/Macros_1.scala',
#  'test/pending/neg/t1557.scala',
#  'test/junit/scala/tools/nsc/backend/jvm/DirectCompileTest.scala',
#  'test/files/run/t3569.flags',
#  'test/files/run/t7899.flags',
#  'test/files/neg/valueclasses-doubledefs.check',
#  'src/asm/scala/tools/asm/util/SignatureChecker.java',
#  'test/files/neg/t6539.check',
#  'test/files/run/t3346g.check',
#  'test/files/jvm/named-args-in-order/Test.scala',
#  'test/files/run/reify_closure1.scala',
#  'src/reflect/scala/reflect/io/VirtualFile.scala',
#  'test/files/run/t6323b.scala',
#  'test/files/run/runtimeEval2.check',
#  'test/files/run/t7008/Impls_Macros_2.scala',
#  'test/files/run/macro-reify-chained2/Impls_Macros_1.scala',
#  'test/files/run/macro-parse-position/Impls_Macros_1.scala',
#  'test/files/buildmanager/t2651_3/A.scala',
#  'test/files/run/t8266-octal-interp.check',
#  'test/files/neg/t7209.scala',
#  'test/files/pos/t1203b/J.java',
#  'test/files/neg/t3240.check',
#  'test/disabled/buildmanager/t2651_1/t2651_1.test',
#  'test/files/run/t8017.flags',
#  'test/files/run/macro-expand-implicit-macro-is-view.check',
#  'test/files/neg/virtpatmat_exhaust_big.scala',
#  'src/library/scala/runtime/AbstractFunction0.scala',
#  'test/junit/scala/collection/convert/NullSafetyTest.scala',
#  'test/disabled/presentation/akka/src/akka/config/ConfigParser.scala',
#  'test/files/buildmanager/t2556_1/t2556_1.check',
#  'src/intellij/test/files/pos/virtpatmat_exhaust_big.scala',
#  'test/attic/files/cli/test2/Main.check.scalaint',
#  'test/files/continuations-run/t5314-3.scala',
#  'src/msil/ch/epfl/lamp/compiler/msil/PropertyInfo.java',
#  'test/files/run/reify_ann1c.scala',
#  'test/files/run/t3346g.scala',
#  'test/files/neg/t8431.check',
#  'test/files/run/inline-access-levels/A_1.scala',
#  'src/scalacheck/org/scalacheck/Test.scala',
#  'test/files/run/macro-toplevel-companion-c.scala',
#  'src/library/scala/runtime/Statics.java',
#  'src/compiler/scala/tools/ant/ScalacShared.scala',
#  'test/files/run/macro-expand-unapply/Test_2.scala',
#  'src/scaladoc/scala/tools/nsc/doc/html/resource/lib/open-sans-v13-latin-700i.ttf',
#  'test/junit/scala/collection/LinearSeqOptimizedTest.scala',
#  'src/swing/scala/swing/Component.scala',
#  'test/files/presentation/t8934.check',
#  'src/compiler/scala/tools/nsc/doc/html/resource/lib/class_diagram.png',
#  'test/files/neg/t7494-multi-right-after/sample_2.flags',
#  'test/files/lib/nest.jar.desired.sha1',
#  'test/files/run/t5269.check',
#  'test/files/neg/hk-existential-lb.check',
#  'src/compiler/scala/tools/nsc/ast/Printers.scala',
#  'test/benchmarks/src/scala/collection/parallel/benchmarks/parallel_array/CountLight.scala',
#  'src/compiler/scala/tools/nsc/util/CachedClassPath.scala',
#  'test/files/neg/macro-enclosing-template/Test_2.scala',
#  'test/files/pos/t7815.scala',
#  'test/files/neg/t5120.check',
#  'src/library/scala/concurrent/impl/AbstractPromise.java',
#  'test/files/run/t6146b.check',
#  'test/files/run/t8048a.check',
#  'test/files/run/t3236/ShortAnnotation.java',
#  'test/files/pos/functions.scala',
#  'test/files/run/t6989.check',
#  'test/scaladoc/run/SI-6580.scala',
#  'src/library/scala/runtime/AbstractFunction17.scala',
#  'test/files/run/reify_newimpl_13.check',
#  'src/intellij/update.sh',
#  'src/library/scala/SerialVersionUID.scala',
#  'test/files/neg/structural.scala',
#  'test/files/run/t8788.check',
#  'test/files/neg/t5702-neg-ugly-xbrace.check',
#  'src/actors/scala/actors/threadpool/LinkedBlockingQueue.java',
#  'test/files/pos/t8523.flags',
#  'test/files/run/constrained-types.scala',
#  'test/files/neg/t421.check',
#  'test/files/neg/t3556.check',
#  'test/files/neg/t4851.check',
#  'test/pending/pos/t1782/Days.java',
#  'src/library/scala/runtime/java8/JFunction6.java',
#  'test/files/run/macro-expand-tparams-optional.flags',
#  'test/files/neg/t5148.check',
#  'test/files/run/virtpatmat_unapplyseq.flags',
#  'src/manual/scala/man1/scaladoc.scala',
#  'src/compiler/scala/tools/asm/tree/analysis/SmallSet.java',
#  'test/files/neg/t6337.scala',
#  'test/files/neg/t1286.check',
#  'test/files/jvm/t7253/JavaClient_1.java',
#  'test/files/pos/Transactions.scala',
#  'test/files/neg/t4283b/ScalaBipp.scala',
#  'test/files/neg/macro-reify-splice-splice/Macros_1.scala',
#  'test/files/run/unreachable.scala',
#  'src/library/scala/xml/EntityRef.scala',
#  'src/library/scala/runtime/java8/JFunction2$mcVIJ$sp.java',
#  'test/pending/neg/t3633/test/Test.scala',
#  'test/files/run/MeterCaseClass.scala',
#  'test/files/pos/t7011.scala',
#  'test/files/neg/t6476-bad-esc-c.scala',
#  'test/files/speclib/.gitignore',
#  'tools/add-copyright-headers',
#  'test/files/neg/macro-invalidusage-badtargs.check',
#  'src/compiler/scala/tools/nsc/CompilerRun.scala',
#  'test/files/pos/t7987/Test_2.scala',
#  'test/files/run/t7171.check',
#  'src/compiler/scala/tools/nsc/doc/html/page/diagram/DiagramStats.scala',
#  'src/compiler/scala/tools/nsc/backend/icode/analysis/ProgramPoint.scala',
#  'test/files/continuations-run/while2.scala',
#  'test/files/neg/t2296a.check',
#  'src/msil/ch/epfl/lamp/compiler/msil/Version.java',
#  'test/files/run/macro-whitebox-dynamic-materialization/Macros_1.scala',
#  'test/files/neg/macro-bundle-trait.check',
#  'test/files/run/t10290.scala',
#  'src/library/scala/runtime/StringFormat.scala',
#  'test/files/run/t5986.scala',
#  'test/files/neg/macro-invalidshape-c.flags',
#  'src/compiler/scala/tools/cmd/Instance.scala',
#  'test/files/pos/t6208.scala',
#  'test/files/continuations-neg/t2949.check',
#  'src/jline/target/scala-2.9.2/classes/scala/tools/jline/internal/TerminalLineSettings.class',
#  'test/files/run/dynamicproxy-invalid-invocaton.scala',
#  'src/compiler/scala/reflect/quasiquotes/Holes.scala',
#  'src/library/scala/runtime/java8/JFunction2$mcVJI$sp.java',
#  'test/files/run/t6181.scala',
#  'test/files/neg/t7285.scala',
#  'src/reflect/scala/tools/nsc/io/VirtualDirectory.scala',
#  'test/files/neg/t6476-bad-esc-b.check',
#  'test/files/run/si5262.scala',
#  'src/library/scala/annotation/inductive.scala',
#  'src/scaladoc/scala/tools/nsc/doc/html/resource/lib/object.svg',
#  'test/files/neg/t6263.scala',
#  'test/files/neg/macro-invalidimpl-b/Macros_Test_2.scala',
#  'test/pending/t7629-view-bounds-removal.flags',
#  'test/files/run/t7805-repl-i.scala',
#  'test/files/run/t8133b/A_1.scala',
#  'test/files/continuations-run/ifelse3.check',
#  'test/files/run/macro-term-declared-in-method.flags',
#  'test/pending/script/dashi/a.scala',
#  'src/compiler/scala/reflect/internal/util/Set.scala',
#  'test/files/run/t10587.scala',
#  'test/files/pos/sd219.scala',
#  'test/files/neg/macro-invalidusage-badargs-typemacros-c/Impls_1.scala',
#  'src/compiler/scala/tools/nsc/doc/html/resource/lib/unselected.png',
#  'test/files/pos/t8237.scala',
#  'test/files/neg/t7834neg.scala',
#  'test/files/run/t6259.scala',
#  'test/files/run/macro-default-params/Macros_1.scala',
#  'test/files/run/t2886.check',
#  'test/files/run/t6320.scala',
#  'src/library/scala/collection/generic/GenericClassManifestTraversableTemplate.scala',
#  'test/files/run/iterator-concat.check',
#  'test/files/neg/macro-keyword-val.scala',
#  'test/files/buildmanager/t2650_4/t2650_4.test',
#  'test/files/run/macro-declared-in-anonymous/Impls_1.scala',
#  'test/files/neg/t512.check',
#  'test/files/neg/t7519-b.check',
#  'test/files/neg/t5903c/Test_2.scala',
#  'src/library/scala/collection/TraversableProxy.scala',
#  'test/files/run/StubErrorReturnTypeFunction2.check',
#  'test/files/run/junitForwarders/Test.java',
#  'src/compiler/scala/tools/nsc/CompileServer.scala',
#  'test/files/pos/t8157-2.10.scala',
#  'test/files/run/reflection-magicsymbols-repl.scala',
#  'test/files/neg/virtpatmat_reach_null.flags',
#  'test/files/run/t4788-separate/C_2.scala',
#  'src/reflect/scala/reflect/internal/pickling/UnPickler.scala',
#  'test/pending/pos/t6161.scala',
#  'test/files/run/t6089.check',
#  'test/files/jvm/t6941.check',
#  'test/files/neg/t8229.scala',
#  'test/files/neg/t7290.check',
#  'src/reflect/scala/reflect/macros/WhiteboxContext.scala',
#  'test/files/scalacheck/quasiquotes/LiftableCaseClassProps.scala',
#  'project/RemoteDependencies.scala',
#  'test/files/scalacheck/quasiquotes/TermConstructionProps.scala',
#  'src/swing/scala/swing/UIElement.scala',
#  'src/reflect/scala/reflect/internal/pickling/Translations.scala',
#  'test/junit/scala/reflect/classloading/LoadingOrder.java',
#  'test/files/run/t7582b/InlineHolder_2.scala',
#  'test/files/lib/enums.jar.desired.sha1',
#  'src/eclipse/repl/.classpath',
#  'test/files/neg/t4928.check',
#  'src/scaladoc/scala/tools/nsc/doc/html/resource/lib/versions.txt',
#  'test/files/neg/macro-invalidimpl-a.flags',
#  'test/files/pos/t6047.scala',
#  'test/files/pos/t10185.flags',
#  'test/files/neg/t1980.flags',
#  'test/files/neg/t7870.check',
#  'test/files/run/t2106.flags',
#  'test/files/run/t5565.scala',
#  'src/eclipse/scaladoc/.classpath',
#  'project/build/SVN.scala',
#  'src/library/scala/runtime/VolatileByteRef.java',
#  'test/scaladoc/resources/t5054_q7.scala',
#  'src/scaladoc/scala/tools/nsc/doc/html/resource/lib/class.svg',
#  'test/files/run/inline-outer/inline-outer_1.scala',
#  'test/files/pos/t7232d.flags',
#  'test/files/neg/macro-enclosing-class/Test_2.scala',
#  'test/files/neg/t5799.check',
#  'src/interactive/scala/tools/nsc/interactive/tests/Tester.scala',
#  'test/files/continuations-neg/function2.scala',
#  'test/pending/pos/t1782/ImplementedBy.java',
#  'test/files/neg/macro-keyword-val.flags',
#  'test/files/pos/t6942/t6942.scala',
#  'test/files/neg/t9111d/A_1.java',
#  'test/files/neg/t6663.scala',
#  'test/files/run/reflection-fancy-java-classes/Foo_1.java',
#  'test/files/pos/package-ob-case.flags',
#  'test/files/neg/macro-invalidusage-badtargs-typemacros-d.flags',
#  'test/files/run/t3368-c.check',
#  'test/files/run/patmat-mix-case-extractor.scala',
#  'test/files/run/annotatedRetyping.check',
#  'test/files/neg/t6446-list/sample_2.flags',
#  'src/compiler/scala/tools/nsc/classpath/TypedClassPath.scala',
#  'test/junit/scala/tools/nsc/backend/jvm/NestedClassesCollectorTest.scala',
#  'src/swing/scala/swing/event/Key.scala',
#  'test/pending/continuations-run/example0.scala',
#  'test/files/neg/abstract-explaintypes.check',
#  'test/files/run/richWrapperEquals.scala',
#  'test/files/neg/byname-implicits-21.check',
#  'test/files/run/t5974.check',
#  'test/files/run/t7120/Run_3.scala',
#  'test/files/pos/t3430.flags',
#  'test/pending/run/reify_fors_newpatmat.check',
#  'src/library/scala/collection/concurrent/TrieMap.scala',
#  'test/files/run/t5905-features.scala',
#  'test/files/neg/t6680a.flags',
#  'test/junit/scala/tools/nsc/backend/bcode/LabelsCleanupUnit2Test.scala',
#  'test/files/neg/macro-override-macro-overrides-alias-b/Macros_Test_2.scala',
#  'test/files/pos/t9178b.flags',
#  'test/files/neg/si7980.scala',
#  'test/files/run/reify_renamed_term_overloaded_method.check',
#  'test/files/neg/macro-invalidret-nontree.flags',
#  'src/actors/scala/actors/threadpool/ThreadFactory.java',
#  'test/files/scalacheck/Ctrie.scala',
#  'test/files/neg/dotless-targs.check',
#  'test/files/presentation/scope-completion-import/Test.scala',
#  'test/files/neg/t6443c.check',
#  'src/compiler/scala/reflect/reify/utils/SymbolTables.scala',
#  'test/files/run/t7046-1/Test_2.scala',
#  'test/files/instrumented/inline-in-constructors/test_3.scala',
#  'src/library/scala/reflect/base/Types.scala',
#  'test/benchmarks/src/scala/collection/parallel/benchmarks/parallel_view/SeqViewBenches.scala',
#  'test/files/neg/macro-blackbox-structural/Test_2.scala',
#  'test/files/neg/t696b.scala',
#  'test/files/run/t4723.scala',
#  'test/pending/neg/t7886.scala',
#  'test/files/run/t6464.scala',
#  'src/compiler/scala/tools/ant/sabbus/antlib.xml',
#  'test/junit/scala/tools/nsc/backend/jvm/GenericSignaturesTest.scala',
#  'test/files/jvm/innerClassAttribute.check',
#  'test/files/neg/t7872b.scala',
#  'src/library/scala/runtime/ByteRef.java',
#  'test/files/pos/t10643.scala',
#  'test/files/pos/t4831.scala',
#  'test/junit/scala/util/RandomUtilTest.scala',
#  'test/pending/pos/sig/sigs.java',
#  'test/files/run/t10069b.scala',
#  'test/files/pos/t3368.flags',
#  'src/jline/target/scala-2.9.2/classes/scala/tools/jline/console/history/MemoryHistory.class',
#  'src/compiler/scala/tools/nsc/ast/parser/BracePatch.scala',
#  'test/files/pos/t8363.scala',
#  'test/files/pos/t6666d.scala',
#  'src/swing/scala/swing/event/InternalFrameClosing.scala',
#  'test/files/run/classmanifests_new_alias.check',
#  'src/library/scala/runtime/ArrayCharSequence.scala',
#  'src/interactive/scala/tools/nsc/interactive/tests/core/CoreTestDefs.scala',
#  'src/library/scala/Serializable.scala',
#  'src/library/scala/annotation/meta/param.scala',
#  'test/files/neg/t8104/Macros_1.scala',
#  'src/compiler/scala/tools/nsc/backend/jvm/PerRunInit.scala',
#  'test/disabled/neg/macro-keyword-type.flags',
#  'test/files/pos/t8841.scala',
#  'test/files/run/t6329_vanilla.scala',
#  'test/files/pos/t8046.scala',
#  'test/files/run/reify_metalevel_breach_-1_refers_to_0_b.scala',
#  'test/files/run/macro-reify-abstypetag-typeparams-tags/Test.scala',
#  'test/junit/scala/tools/nsc/interpreter/TabulatorTest.scala',
#  'test/pending/run/reify_csv.scala',
#  'src/jline/target/resolution-cache/org.scala-lang/jline_2.9.2/2.10.0-SNAPSHOT/resolved.xml.properties',
#  'test/files/neg/package-ob-case.check',
#  'src/compiler/scala/tools/asm/Opcodes.java',
#  'test/files/run/t7337.check',
#  'test/files/run/t7570.scala',
#  'test/files/neg/finitary-error.check',
#  'test/pending/pos/t5954/T_2.scala',
#  'test/files/run/kind-poly14.flags',
#  'test/files/neg/t9040.scala',
#  'src/eclipse/reflect/.project',
#  'src/actors/scala/actors/threadpool/AbstractCollection.java',
#  'test/files/neg/t3873.scala',
#  'src/library/scala/collection/JavaConverters.scala',
#  'test/manual-classpath-test/cp-and-sp-test/orig-src/d/e/C.scala',
#  'test/files/run/inline-access-levels/Test_3.scala',
#  'test/files/run/t7936/Test_1.scala',
#  'test/files/neg/outer-ref-checks.scala',
#  'test/files/neg/t6375.scala',
#  'test/files/run/macro-basic/Test_2.scala',
#  'test/files/neg/macro-invalidimpl-g/Macros_Test_2.scala',
#  'test/files/scalacheck/quasiquotes/TermDeconstructionProps.scala',
#  'test/files/pos/t5887.scala',
#  'test/files/run/reify_ann3.scala',
#  'test/files/run/macro-def-path-dependent-c.flags',
#  'src/scaladoc/scala/tools/nsc/doc/html/resource/lib/source-code-pro-v6-latin-regular.eot',
#  'test/files/run/t5532.scala',
#  'test/files/run/t10650/Test.scala',
#  'test/files/neg/t5060.check',
#  'test/files/pos/t7520.scala',
#  'test/files/pos/t9097.scala',
#  'test/files/run/reify_ann1a.scala',
#  'tools/showPickled',
#  ...}

# %% [markdown]
# ## 7. Who made the most pull requests to a given file?
# <p>When contributing to a project, we might need some guidance. We might find ourselves needing some information regarding the codebase. It is important direct any questions to the right person. Contributors to open source projects generally have other day jobs, so their time is limited. It is important to address our questions to the right people. One way to identify the right target for our inquiries is by using their contribution history.</p>
# <p>We identified <code>src/compiler/scala/reflect/reify/phases/Calculate.scala</code> as being recently changed. We are interested in the top 3 developers who changed that file. Those developers are the ones most likely to have the best understanding of the code.</p>

# %%
# This is the file we are interested in:
file = 'src/compiler/scala/reflect/reify/phases/Calculate.scala'

# Identify the commits that changed the file
file_pr = data[data['file']==file]

# Count the number of changes made by each developer
author_counts = file_pr['user'].value_counts()

# Print the top 3 developers
print(author_counts.head(3))
# Out:
# xeno-by     11
# retronym     5
# soc          4
# Name: user, dtype: int64

# %% [markdown]
# ## 8. Who made the last ten pull requests on a given file?
# <p>Open source projects suffer from fluctuating membership. This makes the problem of finding the right person more challenging: the person has to be knowledgeable <em>and</em> still be involved in the project. A person that contributed a lot in the past might no longer be available (or willing) to help. To get a better understanding, we need to investigate the more recent history of that particular part of the system. </p>
# <p>Like in the previous task, we will look at the history of  <code>src/compiler/scala/reflect/reify/phases/Calculate.scala</code>.</p>

# %%
file = 'src/compiler/scala/reflect/reify/phases/Calculate.scala'

# Select the pull requests that changed the target file
file_pr = data[data['file']==file]

# Merge the obtained results with the pulls DataFrame
joined_pr = pulls.merge(file_pr, on=['pid','user','date'])

# Find the users of the last 10 most recent pull requests
users_last_10 =set(joined_pr.nlargest(10, 'date')['user'])

# Printing the results
users_last_10
# Out:
# {'bjornregnell', 'retronym', 'soc', 'starblood', 'xeno-by', 'zuvizudar'}

# %% [markdown]
# ## 9. The pull requests of two special developers
# <p>Now that we have identified two potential contacts in the projects, we need to find the person who was most involved in the project in recent times. That person is most likely to answer our questions. For each calendar year, we are interested in understanding the number of pull requests the authors submitted. This will give us a high-level image of their contribution trend to the project.</p>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# The developers we are interested in
authors = ['xeno-by', 'soc']

# Get all the developers' pull requests
by_author = pulls[pulls['user'].isin(authors) == True]

# Count the number of pull requests submitted each year
counts = by_author.groupby(['user', by_author['date'].dt.year]).agg({'pid': 'count'})

# Convert the table to a wide format
counts_wide = counts.pivot_table(index='date', columns='user', values='pid', fill_value=0)

# Plot the results
counts_wide.plot(kind = 'bar')
plt.show()

# %% [markdown]
# ## 10. Visualizing the contributions of each developer
# <p>As mentioned before, it is important to make a distinction between the global expertise and contribution levels and the contribution levels at a more granular level (file, submodule, etc.) In our case, we want to see which of our two developers of interest have the most experience with the code in a given file. We will measure experience by the number of pull requests submitted that affect that file and how recent those pull requests were submitted.</p>

# %%
authors = ['xeno-by', 'soc']
file = 'src/compiler/scala/reflect/reify/phases/Calculate.scala'

# Select the pull requests submitted by the authors, from the `data` DataFrame
by_author = data[data['user'].isin(authors)==True]

# Select the pull requests that affect the file
by_file = by_author[by_author['file']==file]

# Group and count the number of PRs done by each user each year
grouped = by_file.groupby(['user', by_file['date'].dt.year]).agg({'pid': 'count'})

# Transform the data into a wide format
by_file_wide = grouped.pivot_table('pid', index='date', columns = 'user', fill_value=0)

# Plot the results
by_file_wide.plot(kind='bar')
